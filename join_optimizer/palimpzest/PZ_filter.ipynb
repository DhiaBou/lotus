# %%
import duckdb, pandas as pd, os
import palimpzest as pz
from dotenv import load_dotenv
load_dotenv(override=False)
import palimpzest.core.elements.records

parquet_path = "../join_optimizer/fashion_product_images/styles.parquet"
details_path = "../join_optimizer/fashion_product_images/styles_details.parquet"
sample_size = 0.002

# %%
df = duckdb.query(f"""
WITH images AS (
  SELECT * FROM parquet_scan('{parquet_path}')
  USING SAMPLE {sample_size*100} PERCENT (reservoir, 80)
)
SELECT
  images.id,
  images.subcategory,
  images.articletype,
  images.basecolour,
  details.price,
  images.productDisplayName,
  styleimages.default.imageURL AS image_url
FROM images, parquet_scan('{details_path}') details
WHERE images.id = details.id
ORDER BY images.id
""").to_df()

# %%
schema = [
    {"name": "id", "type": str, "desc": "product id"},
    {"name": "productDisplayName", "type": str, "desc": "display name"},
    {"name": "price", "type": float, "desc": "price"},
    {"name": "image_url", "type": str, "desc": "remote image url"},
]

class DFReader(pz.DataReader):
    def __init__(self, df):
        super().__init__(schema=schema)
        self.df = df.reset_index(drop=True)
    def __len__(self):
        return len(self.df)
    def __getitem__(self, i):
        r = self.df.iloc[i]
        return {
            "id": str(r["id"]),
            "productDisplayName": str(r["productDisplayName"]),
            "price": float(r["price"]) if pd.notna(r["price"]) else None,
            "image_url": r["image_url"],
        }

ds = pz.Dataset(DFReader(df))

# %%
predicate = (
    "Keep rows where the product in the image (from productDisplayName) "
    "is topwear. "
    "If multiple products appear, decide by the most prominent one."
)

# %%
filtered = ds.sem_filter(predicate, depends_on=["productDisplayName"])
out = filtered.run(min_time=True)  # config optional; defaults are fine for a quick pass
result = out.to_df(cols=[
    "id",
    "productDisplayName",
    "price",
    "image_url"
])
print(result.head())
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Total time: 14.75s
# Total cost: $0.0045
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 2
#       1 filtered = ds.sem_filter(predicate, depends_on=["productDisplayName"])
# ----> 2 out = filtered.run(min_time=True)  # config optional; defaults are fine for a quick pass
#       3 result = out.to_df(cols=[
#       4     # "id",
#       5     "productDisplayName",
#       6     # "price",
#       7     # "image_url"
#       8 ])
#       9 print(result.head())
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/palimpzest/sets.py:405, in Dataset.run(self, config, **kwargs)
#     402 if policy is not None:
#     403     kwargs["policy"] = policy
# --> 405 return QueryProcessorFactory.create_and_run_processor(self, config, **kwargs)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/palimpzest/query/processor/query_processor_factory.py:160, in QueryProcessorFactory.create_and_run_processor(cls, dataset, config, **kwargs)
#     157 processor = cls.create_processor(dataset=dataset, config=config, **kwargs)
#     158 logger.info(f"Created processor: {processor}")
# --> 160 return processor.execute()
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/palimpzest/query/processor/nosentinel_processor.py:23, in NoSentinelQueryProcessor.execute(self)
#      20 execution_stats.start()
#      22 # execute plan(s) according to the optimization strategy
# ---> 23 records, plan_stats = self._execute_best_plan(self.dataset, self.optimizer)
#      25 # update the execution stats to account for the work to execute the final plan
#      26 execution_stats.add_plan_stats(plan_stats)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/palimpzest/query/processor/query_processor.py:89, in QueryProcessor._execute_best_plan(self, dataset, optimizer)
#      86 final_plan = plans[0]
#      88 # execute the plan
# ---> 89 records, plan_stats = self.execution_strategy.execute_plan(plan=final_plan)
#      91 # return the output records and plan stats
#      92 return records, [plan_stats]
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/palimpzest/query/execution/single_threaded_execution_strategy.py:112, in SequentialSingleThreadExecutionStrategy.execute_plan(self, plan)
#     107 # NOTE: we must handle progress manager outside of _exeecute_plan to ensure that it is shut down correctly;
#     108 #       if we don't have the `finally:` branch, then program crashes can cause future program runs to fail
#     109 #       because the progress manager cannot get a handle to the console
#     110 try:
#     111     # execute plan
# --> 112     output_records, plan_stats = self._execute_plan(plan, input_queues, plan_stats)
#     114 finally:
#     115     # finish progress tracking
#     116     self.progress_manager.finish()
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/palimpzest/query/execution/single_threaded_execution_strategy.py:55, in SequentialSingleThreadExecutionStrategy._execute_plan(self, plan, input_queues, plan_stats)
#      52 # otherwise, process the records in the input queue for this operator one at a time
#      53 else:
#      54     for input_record in input_queues[full_op_id]:
# ---> 55         record_set = operator(input_record)
#      56         records.extend(record_set.data_records)
#      57         record_op_stats.extend(record_set.record_op_stats)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/palimpzest/query/operators/filter.py:114, in FilterOp.__call__(self, candidate)
#     111 start_time = time.time()
#     113 # apply the filter operation
# --> 114 field_answers, generation_stats = self.filter(candidate)
#     116 # create and return record set
#     117 record_set = self._create_record_set(
#     118     candidate,
#     119     field_answers["passed_operator"],
#    (...)
#     122     field_answers
#     123 )
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/palimpzest/query/operators/filter.py:256, in LLMFilter.filter(self, candidate)
#     254 # generate output; NOTE: BooleanField is used to indicate the output type; thus, the desc is not needed
#     255 fields = {"passed_operator": BooleanField(desc="")}
# --> 256 field_answers, _, generation_stats, _ = self.generator(candidate, fields, **gen_kwargs)
#     258 return field_answers, generation_stats
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/palimpzest/query/generators/generators.py:364, in BaseGenerator.__call__(self, candidate, fields, json_output, **kwargs)
#     362 completion = None
#     363 try:
# --> 364     completion = self._generate_completion(client, chat_payload, **kwargs)
#     365     end_time = time.time()
#     366     logger.debug(f"Generated completion in {end_time - start_time:.2f} seconds")
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/palimpzest/query/generators/generators.py:475, in OpenAIGenerator._generate_completion(self, client, payload, **kwargs)
#     473 def _generate_completion(self, client: OpenAI, payload: dict, **kwargs) -> ChatCompletion:
#     474     """Generates a completion object using the client (or local model)."""
# --> 475     return client.chat.completions.create(**payload)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/openai/resources/chat/completions/completions.py:929, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     886 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     887 def create(
#     888     self,
#    (...)
#     926     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     927 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     928     validate_response_format(response_format)
# --> 929     return self._post(
#     930         "/chat/completions",
#     931         body=maybe_transform(
#     932             {
#     933                 "messages": messages,
#     934                 "model": model,
#     935                 "audio": audio,
#     936                 "frequency_penalty": frequency_penalty,
#     937                 "function_call": function_call,
#     938                 "functions": functions,
#     939                 "logit_bias": logit_bias,
#     940                 "logprobs": logprobs,
#     941                 "max_completion_tokens": max_completion_tokens,
#     942                 "max_tokens": max_tokens,
#     943                 "metadata": metadata,
#     944                 "modalities": modalities,
#     945                 "n": n,
#     946                 "parallel_tool_calls": parallel_tool_calls,
#     947                 "prediction": prediction,
#     948                 "presence_penalty": presence_penalty,
#     949                 "reasoning_effort": reasoning_effort,
#     950                 "response_format": response_format,
#     951                 "seed": seed,
#     952                 "service_tier": service_tier,
#     953                 "stop": stop,
#     954                 "store": store,
#     955                 "stream": stream,
#     956                 "stream_options": stream_options,
#     957                 "temperature": temperature,
#     958                 "tool_choice": tool_choice,
#     959                 "tools": tools,
#     960                 "top_logprobs": top_logprobs,
#     961                 "top_p": top_p,
#     962                 "user": user,
#     963                 "web_search_options": web_search_options,
#     964             },
#     965             completion_create_params.CompletionCreateParamsStreaming
#     966             if stream
#     967             else completion_create_params.CompletionCreateParamsNonStreaming,
#     968         ),
#     969         options=make_request_options(
#     970             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     971         ),
#     972         cast_to=ChatCompletion,
#     973         stream=stream or False,
#     974         stream_cls=Stream[ChatCompletionChunk],
#     975     )
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/openai/_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1262 def post(
#    1263     self,
#    1264     path: str,
#    (...)
#    1271     stream_cls: type[_StreamT] | None = None,
#    1272 ) -> ResponseT | _StreamT:
#    1273     opts = FinalRequestOptions.construct(
#    1274         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275     )
# -> 1276     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/openai/_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     946 else:
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/openai/_base_client.py:989, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     986 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     988 try:
# --> 989     response = self._client.send(
#     990         request,
#     991         stream=stream or self._should_stream_response_body(request=request),
#     992         **kwargs,
#     993     )
#     994 except httpx.TimeoutException as err:
#     995     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/miniconda3/envs/lotus/lib/python3.10/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/ssl.py:1292, in SSLSocket.recv(self, buflen, flags)
#    1288     if flags != 0:
#    1289         raise ValueError(
#    1290             "non-zero flags not allowed in calls to recv() on %s" %
#    1291             self.__class__)
# -> 1292     return self.read(buflen)
#    1293 else:
#    1294     return super().recv(buflen, flags)
#
# File ~/miniconda3/envs/lotus/lib/python3.10/ssl.py:1165, in SSLSocket.read(self, len, buffer)
#    1163         return self._sslobj.read(len, buffer)
#    1164     else:
# -> 1165         return self._sslobj.read(len)
#    1166 except SSLError as x:
#    1167     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
